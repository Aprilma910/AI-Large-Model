# %%
from langchain.prompts import PromptTemplate
from langchain_community.llms import Tongyi  # 导入通义千问Tongyi模型
import dashscope
import os

# 从环境变量获取 dashscope 的 API Key
api_key = os.environ.get('DASHSCOPE_API_KEY')
dashscope.api_key = api_key
 
# 加载 Tongyi 模型
llm = Tongyi(model_name="qwen-turbo", dashscope_api_key=api_key)  # 使用通义千问qwen-turbo模型

# 创建Prompt Template
prompt = PromptTemplate(
    input_variables=["product"],
    template="What is a good name for a company that makes {product}?",
)

# 新推荐用法：将 prompt 和 llm 组合成一个"可运行序列"
chain = prompt | llm

# 使用 invoke 方法传入输入
result1 = chain.invoke({"product": "colorful socks"})
print(result1)
# Out:
# Here are a few creative and catchy name ideas for a company that makes colorful socks:
#
# 1. **Rainbow Sox**
# 2. **Chromsocks**
# 3. **Sole Mates**
# 4. **Colorful Threads**
# 5. **Happy Socks Co.**
# 6. **Socktastic**
# 7. **FeetFest**
# 8. **Vivid Socks**
# 9. **PopSocks**
# 10. **Artistic Ankles**
#
# Each of these names conveys fun, vibrancy, and individuality—perfect for a brand focused on colorful socks! Which one resonates with you?

# %%
result2 = chain.invoke({"product": "广告设计"})
print(result2)
# Out:
# 'Here are some creative and professional name ideas for a company that specializes in 广告设计 (advertising design):\n\n1. **VisualEcho**  \n2. **CreativeFlair**  \n3. **AdVance Studio**  \n4. **PixelPersuasion**  \n5. **BrandCraft**  \n6. **Visionary Ads**  \n7. **DesignSpark**  \n8. **AdNessence**  \n9. **StoryFrame**  \n10. **ArtOfImpact**  \n\nIf you\'d like to incorporate Chinese elements or make it more culturally relevant, here are a few bilingual options:\n\n11. **美广创意 (MeiGuang Creative)** - Combining "beautiful" (美) and "broad/advertising" (广).  \n12. **视界广告 (ShiJie Ads)** - Meaning "vision world," emphasizing creativity and perspective.  \n13. **灵动设计 (LingDong Design)** - Suggesting lively and innovative designs.  \n\nLet me know if you\'d like help refining these further!'
